# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('./cheating/cheat_sheet.csv')

# Display the data
df
# Out:
#     hole_card1 hole_card2  win_probability
# 0           9♠         9♥           0.3715
# 1           9♠         9♦           0.3720
# 2           9♠         9♣           0.3780
# 3           9♠         T♠           0.3295
# 4           9♠         T♥           0.2875
# ..         ...        ...              ...
# 271         A♠         A♦           0.6810
# 272         A♠         A♣           0.6655
# 273         A♥         A♦           0.6900
# 274         A♥         A♣           0.6995
# 275         A♦         A♣           0.7030
#
# [276 rows x 3 columns]
